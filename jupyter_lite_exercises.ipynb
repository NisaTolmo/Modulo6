# %% [markdown]
# ### Ejercicio 2 - Cree una celda markdown con el título del cuaderno. (1 pto)
#
# # Título del Cuaderno: Introducción a la Ciencia de Datos
#
# ---
#
# ### Ejercicio 3 - Cree una celda markdown para una introducción. (1 pto)
#
# """
# ## Introducción
#
# Este cuaderno presenta una introducción a los conceptos básicos de la Ciencia de Datos. Se exploraran los lenguajes, bibliotecas y herramientas esenciales para el análisis de datos y la creación de modelos predictivos.
# """
#
# ---
#
# ### Ejercicio 4 - Cree una celda markdown para enumerar los lenguajes de la ciencia de datos. (3 ptos)
#
# """
# ## Lenguajes de la Ciencia de Datos
#
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala
# 6. Java
# 7. C/C++
# """
#
# ---
#
# ### Ejercicio 5 - Cree una celda markdown para listar bibliotecas de ciencia de datos. (3 ptos)
#
# """
# ## Bibliotecas de Ciencia de Datos
#
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn
# - Scikit-learn
# - TensorFlow
# - Keras
# - PyTorch
# """
#
# ---
#
# ### Ejercicio 6 - Cree una celda markdown con una tabla de herramientas de Ciencia de Datos. (3 ptos)
#
# """
# ## Herramientas de Ciencia de Datos
#
# | Herramienta       | Descripción                         |
# |------------------|-------------------------------------|
# | Jupyter Notebook  | Entorno de código interactivo       |
# | RStudio           | IDE para R                          |
# | Visual Studio Code| Editor de código ligero             |
# | Apache Hadoop     | Marco de procesamiento de big data  |
# | Apache Spark      | Motor de análisis de big data       |
# """
#
# ---
#
# ### Ejercicio 7 - Cree una celda markdown introduciendo ejemplos de expresiones aritméticas. (1 pto)
#
# """
# ## Ejemplos de Expresiones Aritméticas
#
# - Suma: 3 + 2 = 5
# - Resta: 7 - 4 = 3
# - Multiplicación: 6 * 3 = 18
# - División: 10 / 2 = 5
# - Exponenciación: 2 ** 3 = 8
# """
#
# ---
#
# ### Ejercicio 8 - Cree una celda de código para multiplicar y sumar números. (2 ptos)
#
# # Multiplicación y suma de números
# a = 5
# b = 3
# multiplicacion = a * b
# suma = a + b
# print("Multiplicación:", multiplicacion)
# print("Suma:", suma)
#
# ---
#
# ### Ejercicio 9 - Cree una celda de código para convertir minutos en horas. (2 ptos)
#
# # Conversión de minutos a horas
# minutos = 150
# horas = minutos / 60
# print(f"{minutos} minutos son {horas} horas")
#
# ---
#
# ### Ejercicio 10 - Inserte una celda de código para listar Objetivos. (3 pts)
#
# # Objetivos de Aprendizaje
# objetivos = [
#     "Entender los conceptos básicos de Ciencia de Datos",
#     "Familiarizarse con los lenguajes y bibliotecas más utilizados",
#     "Practicar la creación de código en Jupyter Notebook",
#     "Aprender a compartir proyectos de Ciencia de Datos en GitHub"
# ]
#
# for i, objetivo in enumerate(objetivos, start=1):
#     print(f"{i}. {objetivo}")
#
# ---
#
# ### Ejercicio 11 - Cree una celda markdown para indicar el nombre del Autor. (2 ptos)
#
# """
# ## Autor
#
# Nombre: Nisa
# """
#
# ---
#
# ### Ejercicio 12 - Comparta su cuaderno a través de GitHub (3 pts)
#
# """
# Para compartir este cuaderno a través de GitHub, sigue los siguientes pasos:
#
# 1. Accede a tu cuenta de GitHub.
# 2. Crea un nuevo repositorio o usa uno existente.
# 3. Sube el archivo .ipynb de tu cuaderno a la sección de "Archivos" de tu repositorio.
# 4. Copia y comparte la URL del repositorio.
# """
#
# ---
#
# ### Ejercicio 13 - Haga una captura de pantalla de la primera página del cuaderno. (1 pto)
#
# """
# Para capturar la primera página de este cuaderno:
#
# 1. Abre el cuaderno en tu navegador.
# 2. Usa la función de captura de pantalla de tu sistema operativo (por ejemplo, tecla "Impr Pant" en Windows o "Shift + Command + 4" en macOS).
# 3. Guarda la imagen en formato .png o .jpg.
# 4. Sube la imagen al repositorio de GitHub o adjúntala según sea necesario.
# """
